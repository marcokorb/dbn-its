# %%
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.lib.dynamicBN as gdyn
from its.apps.its.models import Course
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AppRegistryNotReady                       Traceback (most recent call last)
# <ipython-input-4-3bdf818e407d> in <module>
#       3 import pyAgrum.lib.notebook as gnb
#       4 import pyAgrum.lib.dynamicBN as gdyn
# ----> 5 from its.apps.its.models import Course
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~/Misc/dbn-its/its/apps/its/models/__init__.py in <module>
#      17 ]
#      18
# ---> 19 from .alternative import Alternative
#      20 from. course import (
#      21         Course,
#
# ~/Misc/dbn-its/its/apps/its/models/alternative.py in <module>
#       7 from django.utils.translation import gettext_lazy as _
#       8
# ----> 9 from .question import Question
#      10
#      11
#
# ~/Misc/dbn-its/its/apps/its/models/question.py in <module>
#       6 from django.utils.translation import gettext_lazy as _
#       7
# ----> 8 from .evidence import Evidence
#       9
#      10
#
# ~/Misc/dbn-its/its/apps/its/models/evidence.py in <module>
#       6 ]
#       7
# ----> 8 from django.contrib.auth.models import User
#       9 from django.db import models
#      10 from django.utils.translation import gettext_lazy as _
#
# ~/Misc/dbn-its/venv/lib/python3.8/site-packages/django/contrib/auth/models.py in <module>
#       1 from django.contrib import auth
# ----> 2 from django.contrib.auth.base_user import AbstractBaseUser, BaseUserManager
#       3 from django.contrib.contenttypes.models import ContentType
#       4 from django.core.exceptions import PermissionDenied
#       5 from django.core.mail import send_mail
#
# ~/Misc/dbn-its/venv/lib/python3.8/site-packages/django/contrib/auth/base_user.py in <module>
#      46
#      47
# ---> 48 class AbstractBaseUser(models.Model):
#      49     password = models.CharField(_('password'), max_length=128)
#      50     last_login = models.DateTimeField(_('last login'), blank=True, null=True)
#
# ~/Misc/dbn-its/venv/lib/python3.8/site-packages/django/db/models/base.py in __new__(cls, name, bases, attrs, **kwargs)
#     106
#     107         # Look for an application configuration to attach the model to.
# --> 108         app_config = apps.get_containing_app_config(module)
#     109
#     110         if getattr(meta, 'app_label', None) is None:
#
# ~/Misc/dbn-its/venv/lib/python3.8/site-packages/django/apps/registry.py in get_containing_app_config(self, object_name)
#     251         Return None if the object isn't in any registered app config.
#     252         """
# --> 253         self.check_apps_ready()
#     254         candidates = []
#     255         for app_config in self.app_configs.values():
#
# ~/Misc/dbn-its/venv/lib/python3.8/site-packages/django/apps/registry.py in check_apps_ready(self)
#     134             # exception.
#     135             settings.INSTALLED_APPS
# --> 136             raise AppRegistryNotReady("Apps aren't loaded yet.")
#     137
#     138     def check_models_ready(self):
#
# AppRegistryNotReady: Apps aren't loaded yet.

# %%
twodbn = gum.BayesNet()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'twodbn = gum.BayesNet()\nlocals()',
#   "import os\nimport pyAgrum as gum\nimport pyAgrum.lib.notebook as gnb\nimport pyAgrum.lib.dynamicBN as gdyn\nget_ipython().run_line_magic('matplotlib', 'inline')",
#   'twodbn = gum.BayesNet()\nlocals()'],
#  '_oh': {},
#  '_dh': ['/home/kmarcorb/Misc/dbn-its'],
#  'In': ['',
#   'twodbn = gum.BayesNet()\nlocals()',
#   "import os\nimport pyAgrum as gum\nimport pyAgrum.lib.notebook as gnb\nimport pyAgrum.lib.dynamicBN as gdyn\nget_ipython().run_line_magic('matplotlib', 'inline')",
#   'twodbn = gum.BayesNet()\nlocals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f274f638670>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f274c58ea30>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f274c58ea30>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': 'import os\nimport pyAgrum as gum\nimport pyAgrum.lib.notebook as gnb\nimport pyAgrum.lib.dynamicBN as gdyn\n%matplotlib inline',
#  '_ii': 'twodbn = gum.BayesNet()\nlocals()',
#  '_iii': '',
#  '_i1': 'twodbn = gum.BayesNet()\nlocals()',
#  '_i2': 'import os\nimport pyAgrum as gum\nimport pyAgrum.lib.notebook as gnb\nimport pyAgrum.lib.dynamicBN as gdyn\n%matplotlib inline',
#  'os': <module 'os' from '/usr/lib/python3.8/os.py'>,
#  'gum': <module 'pyAgrum' from '/home/kmarcorb/Misc/dbn-its/venv/lib/python3.8/site-packages/pyAgrum/__init__.py'>,
#  'gnb': <module 'pyAgrum.lib.notebook' from '/home/kmarcorb/Misc/dbn-its/venv/lib/python3.8/site-packages/pyAgrum/lib/notebook.py'>,
#  'gdyn': <module 'pyAgrum.lib.dynamicBN' from '/home/kmarcorb/Misc/dbn-its/venv/lib/python3.8/site-packages/pyAgrum/lib/dynamicBN.py'>,
#  '_i3': 'twodbn = gum.BayesNet()\nlocals()',
#  'twodbn': (gum::BayesNet<double>@0x207f0c0) BN{nodes: 0, arcs: 0, domainSize: 1, dim: 0}}

# %%
# Subjects nodes
subjects_nodes = ['ca0', 'co0', 'h0', 'cat', 'cot', 'ht']

[
    twodbn.add(gum.LabelizedVariable(s, s, 2)) 
    for s in subjects_nodes
]
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
evidences_nodes = ['evca0', 'evco0', 'evh0', 'evcat', 'evcot', 'evht']

[
    twodbn.add(gum.LabelizedVariable(s, s, 2)) 
    for s in evidences_nodes
]
# Out:
# [6, 7, 8, 9, 10, 11]

# %%
twodbn.addArc('ca0', 'h0')
twodbn.addArc('co0', 'h0')
twodbn.addArc('cat', 'ht')
twodbn.addArc('cot', 'ht')


twodbn.addArc('ca0', 'evca0')
twodbn.addArc('co0', 'evco0')
twodbn.addArc('h0', 'evh0')
twodbn.addArc('cat', 'evcat')
twodbn.addArc('cot', 'evcot')
twodbn.addArc('ht', 'evht')

twodbn.addArc('ca0', 'cat')
twodbn.addArc('co0', 'cot')
twodbn.addArc('h0', 'ht')

# %%
twodbn.generateCPTs()

# %%
gnb.showBN(twodbn, size="20")

# %%
gdyn.showTimeSlices(twodbn, size="20")

# %%
T=6

dbn = gdyn.unroll2TBN(twodbn,T)
gdyn.showTimeSlices(dbn, size="20")
